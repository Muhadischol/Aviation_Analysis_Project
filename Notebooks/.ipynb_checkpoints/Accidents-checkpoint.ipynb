# %% [markdown]
# # Aviation Accidents Analysis

# %% [markdown]
# ## 1. Overview
#
# A company I am working with is planning to diversify its portfolio by exploring new areas, particularly the aviation industry. The leadership is interested in the risks associated with aircraft operations, mainly safety and reliability. It is on that background that as a senior data scientist in the company that the management tusked me with the responsibility of carrying out data analysis to assist the management in making informed investment decisions to determine which aircraft presents the lowest operational risk.

# %% [markdown]
# ## 2. Business Understanding
# The company's goal is to identify the safest and most reliable aircraft to purchase based on an analysis of accident and incident data collected over the years. Therefore, the company wants to answer the following questions before taking any steps to make a purchase.
# The company wants aircraft:
#
# * That is not accident-prone/low accident frequency.
# * If ever involved in an accident, then a low number of deaths and injuries.
# * For aircraft that are frequently involved in accidents, who built their engines, and what models are they?
# * Are the aircraft that are frequently accident-prone professionally or amateur-built?

# %% [markdown]
# ## 3. Data Science Understanding
# Analyze accident data collected over the years to establish which aircraft has the lowest risk by using risk indicators such as accident frequency, fatality rate, and severity of injuries. This will answer the questions such as;
# * Which aircraft models have the lowest number of reported accidents in the dataset?
# * What is the accident rate per aircraft model, considering how often each model appears?
# * Among aircraft with high accident frequency, what are the common engine manufacturers and engine models?
# * Is there a relationship between engine builder and accident frequency?

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Loading accident data to the notebook
aviation_data = pd.read_csv("../Data/AviationData.csv", index_col = 0, encoding = "latin1", low_memory = False)

# %% [markdown]
# ### 3.1 exploring data

# %%
aviation_data.head() # checking the first five rows of the dataframe
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country   Latitude   Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States        NaN         NaN
# 20001218X45447   BRIDGEPORT, CA  United States        NaN         NaN
# 20061025X01555    Saltville, VA  United States  36.922223  -81.878056
# 20001218X45448       EUREKA, CA  United States        NaN         NaN
# 20041105X01764       Canton, OH  United States        NaN         NaN
#
#                Airport.Code Airport.Name Injury.Severity  ...  \
# Event.Id                                                  ...
# 20001218X45444          NaN          NaN        Fatal(2)  ...
# 20001218X45447          NaN          NaN        Fatal(4)  ...
# 20061025X01555          NaN          NaN        Fatal(3)  ...
# 20001218X45448          NaN          NaN        Fatal(2)  ...
# 20041105X01764          NaN          NaN        Fatal(1)  ...
#
#                Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444          Personal         NaN                  2.0
# 20001218X45447          Personal         NaN                  4.0
# 20061025X01555          Personal         NaN                  3.0
# 20001218X45448          Personal         NaN                  2.0
# 20041105X01764          Personal         NaN                  1.0
#
#                Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                    0.0                  0.0             0.0
# 20001218X45447                    0.0                  0.0             0.0
# 20061025X01555                    NaN                  NaN             NaN
# 20001218X45448                    0.0                  0.0             0.0
# 20041105X01764                    2.0                  NaN             0.0
#
#                 Weather.Condition Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                Cruise  Probable Cause
# 20001218X45447                UNK               Unknown  Probable Cause
# 20061025X01555                IMC                Cruise  Probable Cause
# 20001218X45448                IMC                Cruise  Probable Cause
# 20041105X01764                VMC              Approach  Probable Cause
#
#                Publication.Date
# Event.Id
# 20001218X45444              NaN
# 20001218X45447       19-09-1996
# 20061025X01555       26-02-2007
# 20001218X45448       12-09-2000
# 20041105X01764       16-04-1980
#
# [5 rows x 30 columns]

# %%
aviation_data.tail() # chwcking the last five rows of the dataframe
# Out:
#                Investigation.Type Accident.Number  Event.Date       Location  \
# Event.Id
# 20221227106491           Accident      ERA23LA093  2022-12-26  Annapolis, MD
# 20221227106494           Accident      ERA23LA095  2022-12-26    Hampton, NH
# 20221227106497           Accident      WPR23LA075  2022-12-26     Payson, AZ
# 20221227106498           Accident      WPR23LA076  2022-12-26     Morgan, UT
# 20221230106513           Accident      ERA23LA097  2022-12-29     Athens, GA
#
#                       Country Latitude Longitude Airport.Code Airport.Name  \
# Event.Id
# 20221227106491  United States      NaN       NaN          NaN          NaN
# 20221227106494  United States      NaN       NaN          NaN          NaN
# 20221227106497  United States  341525N  1112021W          PAN       PAYSON
# 20221227106498  United States      NaN       NaN          NaN          NaN
# 20221230106513  United States      NaN       NaN          NaN          NaN
#
#                Injury.Severity  ... Purpose.of.flight         Air.carrier  \
# Event.Id                        ...
# 20221227106491           Minor  ...          Personal                 NaN
# 20221227106494             NaN  ...               NaN                 NaN
# 20221227106497       Non-Fatal  ...          Personal                 NaN
# 20221227106498             NaN  ...          Personal  MC CESSNA 210N LLC
# 20221230106513           Minor  ...          Personal                 NaN
#
#                Total.Fatal.Injuries Total.Serious.Injuries  \
# Event.Id
# 20221227106491                  0.0                    1.0
# 20221227106494                  0.0                    0.0
# 20221227106497                  0.0                    0.0
# 20221227106498                  0.0                    0.0
# 20221230106513                  0.0                    1.0
#
#                Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Id
# 20221227106491                  0.0             0.0                NaN
# 20221227106494                  0.0             0.0                NaN
# 20221227106497                  0.0             1.0                VMC
# 20221227106498                  0.0             0.0                NaN
# 20221230106513                  0.0             1.0                NaN
#
#                Broad.phase.of.flight Report.Status Publication.Date
# Event.Id
# 20221227106491                   NaN           NaN       29-12-2022
# 20221227106494                   NaN           NaN              NaN
# 20221227106497                   NaN           NaN       27-12-2022
# 20221227106498                   NaN           NaN              NaN
# 20221230106513                   NaN           NaN       30-12-2022
#
# [5 rows x 30 columns]

# %%
aviation_data.info() # getting concise information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Latitude                34382 non-null  object
#  6   Longitude               34373 non-null  object
#  7   Airport.Code            50132 non-null  object
#  8   Airport.Name            52704 non-null  object
#  9   Injury.Severity         87889 non-null  object
#  10  Aircraft.damage         85695 non-null  object
#  11  Aircraft.Category       32287 non-null  object
#  12  Registration.Number     87507 non-null  object
#  13  Make                    88826 non-null  object
#  14  Model                   88797 non-null  object
#  15  Amateur.Built           88787 non-null  object
#  16  Number.of.Engines       82805 non-null  float64
#  17  Engine.Type             81793 non-null  object
#  18  FAR.Description         32023 non-null  object
#  19  Schedule                12582 non-null  object
#  20  Purpose.of.flight       82697 non-null  object
#  21  Air.carrier             16648 non-null  object
#  22  Total.Fatal.Injuries    77488 non-null  float64
#  23  Total.Serious.Injuries  76379 non-null  float64
#  24  Total.Minor.Injuries    76956 non-null  float64
#  25  Total.Uninjured         82977 non-null  float64
#  26  Weather.Condition       84397 non-null  object
#  27  Broad.phase.of.flight   61724 non-null  object
#  28  Report.Status           82505 non-null  object
#  29  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(25)
# memory usage: 21.0+ MB

# %% [markdown]
# All the columns have missing values except the first three.

# %%
aviation_data.shape # checking the dataframe dimensions, i.e number of rows and cloumns in the dataframe.
# Out:
# (88889, 30)

# %% [markdown]
# Dataset contains 88,889 rows and 30 columns.

# %% [markdown]
# ## 4. Data Preparation and cleaning

# %% [markdown]
# ### 4.1 Checking for missing values

# %%
aviation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Latitude                34382 non-null  object
#  6   Longitude               34373 non-null  object
#  7   Airport.Code            50132 non-null  object
#  8   Airport.Name            52704 non-null  object
#  9   Injury.Severity         87889 non-null  object
#  10  Aircraft.damage         85695 non-null  object
#  11  Aircraft.Category       32287 non-null  object
#  12  Registration.Number     87507 non-null  object
#  13  Make                    88826 non-null  object
#  14  Model                   88797 non-null  object
#  15  Amateur.Built           88787 non-null  object
#  16  Number.of.Engines       82805 non-null  float64
#  17  Engine.Type             81793 non-null  object
#  18  FAR.Description         32023 non-null  object
#  19  Schedule                12582 non-null  object
#  20  Purpose.of.flight       82697 non-null  object
#  21  Air.carrier             16648 non-null  object
#  22  Total.Fatal.Injuries    77488 non-null  float64
#  23  Total.Serious.Injuries  76379 non-null  float64
#  24  Total.Minor.Injuries    76956 non-null  float64
#  25  Total.Uninjured         82977 non-null  float64
#  26  Weather.Condition       84397 non-null  object
#  27  Broad.phase.of.flight   61724 non-null  object
#  28  Report.Status           82505 non-null  object
#  29  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(25)
# memory usage: 21.0+ MB

# %%
# checking for number of missing values per a column
aviation_data.isnull().sum()
# Out:
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# Report.Status              6384
# Publication.Date          13771
# dtype: int64

# %%
missing_values_percentage= aviation_data.isnull().mean().sort_values(ascending = False) * 100
missing_values_percentage
# Out:
# Schedule                  85.845268
# Air.carrier               81.271023
# FAR.Description           63.974170
# Aircraft.Category         63.677170
# Longitude                 61.330423
# Latitude                  61.320298
# Airport.Code              43.601570
# Airport.Name              40.708074
# Broad.phase.of.flight     30.560587
# Publication.Date          15.492356
# Total.Serious.Injuries    14.073732
# Total.Minor.Injuries      13.424608
# Total.Fatal.Injuries      12.826109
# Engine.Type                7.982990
# Report.Status              7.181991
# Purpose.of.flight          6.965991
# Number.of.Engines          6.844491
# Total.Uninjured            6.650992
# Weather.Condition          5.053494
# Aircraft.damage            3.593246
# Registration.Number        1.554748
# Injury.Severity            1.124999
# Country                    0.254250
# Amateur.Built              0.114750
# Model                      0.103500
# Make                       0.070875
# Location                   0.058500
# Accident.Number            0.000000
# Event.Date                 0.000000
# Investigation.Type         0.000000
# dtype: float64

# %%
# columns with more than 60 percent missing values
columns_to_drop = missing_values_percentage.head(6) 
columns_to_drop
# Out:
# Schedule             85.845268
# Air.carrier          81.271023
# FAR.Description      63.974170
# Aircraft.Category    63.677170
# Longitude            61.330423
# Latitude             61.320298
# dtype: float64

# %%
# Dropping columns that have more than 60 percent missing values
aviation_data = aviation_data.drop(columns= columns_to_drop.index)
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States          NaN          NaN
# 20001218X45447   BRIDGEPORT, CA  United States          NaN          NaN
# 20061025X01555    Saltville, VA  United States          NaN          NaN
# 20001218X45448       EUREKA, CA  United States          NaN          NaN
# 20041105X01764       Canton, OH  United States          NaN          NaN
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States          NaN          NaN
# 20221227106494      Hampton, NH  United States          NaN          NaN
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States          NaN          NaN
# 20221230106513       Athens, GA  United States          NaN          NaN
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor             NaN              N1867H  ...
# 20221227106494             NaN             NaN              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498             NaN             NaN              N210CU  ...
# 20221230106513           Minor             NaN              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764            NaN          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491            NaN          Personal                  0.0
# 20221227106494            NaN               NaN                  0.0
# 20221227106497            NaN          Personal                  0.0
# 20221227106498            NaN          Personal                  0.0
# 20221230106513            NaN          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     NaN                  NaN             NaN
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  NaN             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491                NaN                    NaN             NaN
# 20221227106494                NaN                    NaN             NaN
# 20221227106497                VMC                    NaN             NaN
# 20221227106498                NaN                    NaN             NaN
# 20221230106513                NaN                    NaN             NaN
#
#                 Publication.Date
# Event.Id
# 20001218X45444               NaN
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494               NaN
# 20221227106497        27-12-2022
# 20221227106498               NaN
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
aviation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Airport.Code            50132 non-null  object
#  6   Airport.Name            52704 non-null  object
#  7   Injury.Severity         87889 non-null  object
#  8   Aircraft.damage         85695 non-null  object
#  9   Registration.Number     87507 non-null  object
#  10  Make                    88826 non-null  object
#  11  Model                   88797 non-null  object
#  12  Amateur.Built           88787 non-null  object
#  13  Number.of.Engines       82805 non-null  float64
#  14  Engine.Type             81793 non-null  object
#  15  Purpose.of.flight       82697 non-null  object
#  16  Total.Fatal.Injuries    77488 non-null  float64
#  17  Total.Serious.Injuries  76379 non-null  float64
#  18  Total.Minor.Injuries    76956 non-null  float64
#  19  Total.Uninjured         82977 non-null  float64
#  20  Weather.Condition       84397 non-null  object
#  21  Broad.phase.of.flight   61724 non-null  object
#  22  Report.Status           82505 non-null  object
#  23  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(19)
# memory usage: 17.0+ MB

# %% [markdown]
# ### 4.2 Filling the missing values

# %%
# creating list of categorical columns
categorical_columns = ["Investigation.Type", "Accident.Number", "Event.Date", "Location", "Country", "Airport.Code", "Airport.Name", "Injury.Severity", "Aircraft.damage", "Registration.Number", "Make", "Model", "Amateur.Built", "Purpose.of.flight", "Weather.Condition", "Broad.phase.of.flight", "Report.Status","Publication.Date"]
categorical_columns
# Out:
# ['Investigation.Type',
#  'Accident.Number',
#  'Event.Date',
#  'Location',
#  'Country',
#  'Airport.Code',
#  'Airport.Name',
#  'Injury.Severity',
#  'Aircraft.damage',
#  'Registration.Number',
#  'Make',
#  'Model',
#  'Amateur.Built',
#  'Purpose.of.flight',
#  'Weather.Condition',
#  'Broad.phase.of.flight',
#  'Report.Status',
#  'Publication.Date']

# %%
# Filling categorical columns with unknown as a value
aviation_data[categorical_columns] = aviation_data[categorical_columns].fillna("unknown")
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      unknown      unknown
# 20001218X45447   BRIDGEPORT, CA  United States      unknown      unknown
# 20061025X01555    Saltville, VA  United States      unknown      unknown
# 20001218X45448       EUREKA, CA  United States      unknown      unknown
# 20041105X01764       Canton, OH  United States      unknown      unknown
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States      unknown      unknown
# 20221227106494      Hampton, NH  United States      unknown      unknown
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States      unknown      unknown
# 20221230106513       Athens, GA  United States      unknown      unknown
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor         unknown              N1867H  ...
# 20221227106494         unknown         unknown              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498         unknown         unknown              N210CU  ...
# 20221230106513           Minor         unknown              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764            NaN          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491            NaN          Personal                  0.0
# 20221227106494            NaN           unknown                  0.0
# 20221227106497            NaN          Personal                  0.0
# 20221227106498            NaN          Personal                  0.0
# 20221230106513            NaN          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     NaN                  NaN             NaN
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  NaN             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491            unknown                unknown         unknown
# 20221227106494            unknown                unknown         unknown
# 20221227106497                VMC                unknown         unknown
# 20221227106498            unknown                unknown         unknown
# 20221230106513            unknown                unknown         unknown
#
#                 Publication.Date
# Event.Id
# 20001218X45444           unknown
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494           unknown
# 20221227106497        27-12-2022
# 20221227106498           unknown
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
# choosing 10 random columns to check if missing values have been filled
aviation_data.sample(10)
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20020917X02959           Accident      CHI82DA220  1982-06-20
# 20001212X16596           Accident      FTW91DRD03  1991-03-17
# 20130508X33146           Accident      ANC13CA043  2013-05-05
# 20001214X43330           Accident      FTW83FRG05  1983-06-29
# 20200817X14856           Accident      CEN20CA348  2020-08-17
# 20001212X22146           Accident      DEN01LA010  2000-10-30
# 20190905X63951           Accident      GAA19CA526  2019-09-05
# 20050831X01349           Accident      SEA05LA179  2005-08-22
# 20001208X07307           Accident      IAD97LA044  1997-01-18
# 20001205X00134           Accident      CHI99LA088  1999-02-06
#
#                            Location        Country Airport.Code  \
# Event.Id
# 20020917X02959           HOBART, IN  United States          3HO
# 20001212X16596           BONITA, LA  United States      unknown
# 20130508X33146         Soldotna, AK  United States         PASX
# 20001214X43330   LYTTON SPRINGS, TX  United States      unknown
# 20200817X14856      League City, TX  United States      unknown
# 20001212X22146      ALBUQUERQUE, NM  United States          4AC
# 20190905X63951           Glendo, WY  United States          76V
# 20050831X01349         RICHLAND, WA  United States      unknown
# 20001208X07307  UNIVERSITY PARK, PA  United States          UNV
# 20001205X00134          HILLMAN, MI  United States          Y95
#
#                     Airport.Name Injury.Severity Aircraft.damage  \
# Event.Id
# 20020917X02959            HOBART       Non-Fatal     Substantial
# 20001212X16596           unknown       Non-Fatal     Substantial
# 20130508X33146  Soldotna Airport       Non-Fatal     Substantial
# 20001214X43330           unknown        Fatal(1)         unknown
# 20200817X14856           unknown       Non-Fatal     Substantial
# 20001212X22146          CORONADO       Non-Fatal     Substantial
# 20190905X63951   Thomas Memorial       Non-Fatal     Substantial
# 20050831X01349           unknown       Non-Fatal     Substantial
# 20001208X07307   UNIVERSITY PARK       Non-Fatal     Substantial
# 20001205X00134   HILLMAN AIRPORT       Non-Fatal     Substantial
#
#                Registration.Number  ...    Engine.Type   Purpose.of.flight  \
# Event.Id                            ...
# 20020917X02959              N897SP  ...  Reciprocating            Personal
# 20001212X16596               N9685  ...  Reciprocating  Aerial Application
# 20130508X33146              N4772M  ...  Reciprocating       Instructional
# 20001214X43330              N7717V  ...  Reciprocating  Aerial Application
# 20200817X14856              N502BK  ...  Reciprocating            Personal
# 20001212X22146               N47BS  ...  Reciprocating            Personal
# 20190905X63951              N14961  ...  Reciprocating            Personal
# 20050831X01349              N7546T  ...  Reciprocating            Personal
# 20001208X07307              N2803A  ...  Reciprocating            Personal
# 20001205X00134              N3332J  ...  Reciprocating            Personal
#
#                Total.Fatal.Injuries  Total.Serious.Injuries  \
# Event.Id
# 20020917X02959                  0.0                     0.0
# 20001212X16596                  0.0                     0.0
# 20130508X33146                  0.0                     0.0
# 20001214X43330                  1.0                     0.0
# 20200817X14856                  0.0                     0.0
# 20001212X22146                  0.0                     0.0
# 20190905X63951                  0.0                     0.0
# 20050831X01349                  NaN                     NaN
# 20001208X07307                  0.0                     0.0
# 20001205X00134                  0.0                     0.0
#
#                Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Id
# 20020917X02959                  1.0             0.0                VMC
# 20001212X16596                  0.0             1.0                VMC
# 20130508X33146                  0.0             2.0                VMC
# 20001214X43330                  0.0             0.0                VMC
# 20200817X14856                  0.0             1.0                VMC
# 20001212X22146                  0.0             1.0                VMC
# 20190905X63951                  0.0             1.0                VMC
# 20050831X01349                  NaN             1.0                VMC
# 20001208X07307                  0.0             2.0                IMC
# 20001205X00134                  0.0             2.0                VMC
#
#                 Broad.phase.of.flight  \
# Event.Id
# 20020917X02959                Takeoff
# 20001212X16596                 Cruise
# 20130508X33146                unknown
# 20001214X43330            Maneuvering
# 20200817X14856                unknown
# 20001212X22146               Approach
# 20190905X63951                unknown
# 20050831X01349                Descent
# 20001208X07307                Takeoff
# 20001205X00134                Landing
#
#                                                     Report.Status  \
# Event.Id
# 20020917X02959                                     Probable Cause
# 20001212X16596                                     Probable Cause
# 20130508X33146  The flight instructor's inadequate supervision...
# 20001214X43330                                     Probable Cause
# 20200817X14856  The pilot's failure to maintain airplane contr...
# 20001212X22146                                     Probable Cause
# 20190905X63951  The pilot's overapplication of brakes during t...
# 20050831X01349                                     Probable Cause
# 20001208X07307                                     Probable Cause
# 20001205X00134                                     Probable Cause
#
#                 Publication.Date
# Event.Id
# 20020917X02959        20-06-1983
# 20001212X16596        31-03-1993
# 20130508X33146        25-09-2020
# 20001214X43330           unknown
# 20200817X14856        02-02-2021
# 20001212X22146        02-07-2001
# 20190905X63951        26-09-2020
# 20050831X01349        27-10-2005
# 20001208X07307        21-05-1998
# 20001205X00134        07-09-2000
#
# [10 rows x 24 columns]

# %%
# creating a list of categorical columns
numericals_columns = ["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Uninjured", "Number.of.Engines"]
numericals_columns
# Out:
# ['Total.Fatal.Injuries',
#  'Total.Serious.Injuries',
#  'Total.Minor.Injuries',
#  'Total.Uninjured',
#  'Number.of.Engines']

# %%
# Filling numerical columns with zeros
aviation_data[numericals_columns] = aviation_data[numericals_columns].fillna(0)
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      unknown      unknown
# 20001218X45447   BRIDGEPORT, CA  United States      unknown      unknown
# 20061025X01555    Saltville, VA  United States      unknown      unknown
# 20001218X45448       EUREKA, CA  United States      unknown      unknown
# 20041105X01764       Canton, OH  United States      unknown      unknown
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States      unknown      unknown
# 20221227106494      Hampton, NH  United States      unknown      unknown
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States      unknown      unknown
# 20221230106513       Athens, GA  United States      unknown      unknown
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor         unknown              N1867H  ...
# 20221227106494         unknown         unknown              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498         unknown         unknown              N210CU  ...
# 20221230106513           Minor         unknown              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764            NaN          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491            NaN          Personal                  0.0
# 20221227106494            NaN           unknown                  0.0
# 20221227106497            NaN          Personal                  0.0
# 20221227106498            NaN          Personal                  0.0
# 20221230106513            NaN          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     0.0                  0.0             0.0
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  0.0             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491            unknown                unknown         unknown
# 20221227106494            unknown                unknown         unknown
# 20221227106497                VMC                unknown         unknown
# 20221227106498            unknown                unknown         unknown
# 20221230106513            unknown                unknown         unknown
#
#                 Publication.Date
# Event.Id
# 20001218X45444           unknown
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494           unknown
# 20221227106497        27-12-2022
# 20221227106498           unknown
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
# checking to see if numerical cols have been effectively filled with zeros.
aviation_data.sample(10)
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20050811X01221           Accident      NYC05LA131  2005-08-07
# 20001208X06951           Accident      MIA97RA005  1996-10-09
# 20001212X20908           Accident      NYC00LA126  2000-04-30
# 20060323X00339           Accident      ANC06LA028  2006-03-23
# 20001207X04926           Accident      SEA96LA017  1995-11-15
# 20170724X70559           Accident      CEN17LA283  2017-07-22
# 20001214X37681           Accident      ANC85MA183  1985-09-25
# 20190515X71620           Accident      GAA19WA265  2019-05-04
# 20030718X01154           Accident      ANC03LA079  2003-07-14
# 20151221X34338           Accident      GAA16CA085  2015-12-12
#
#                                  Location         Country Airport.Code  \
# Event.Id
# 20050811X01221            FARMINGDALE, NJ   United States          BLM
# 20001208X06951     ANDROS ISLAND, BAHAMAS         Bahamas      unknown
# 20001212X20908              POTTSTOWN, PA   United States          PTW
# 20060323X00339            KAILUA-KONA, HI   United States         PHKO
# 20001207X04926              LA GRANDE, OR   United States          LGD
# 20170724X70559                 Austin, TX   United States      unknown
# 20001214X37681               UNALASKA, AK   United States          DUT
# 20190515X71620  Edinburgh, United Kingdom  United Kingdom      unknown
# 20030718X01154                WASILLA, AK   United States         PAWS
# 20151221X34338                  Tracy, CA   United States          1Q4
#
#                               Airport.Name Injury.Severity Aircraft.damage  \
# Event.Id
# 20050811X01221  Monmouth Executive Airport       Non-Fatal     Substantial
# 20001208X06951                     unknown       Non-Fatal     Substantial
# 20001212X20908          POTTSTOWN LIMERICK       Non-Fatal     Substantial
# 20060323X00339  Kona International Airport       Non-Fatal     Substantial
# 20001207X04926                   LA GRANDE       Non-Fatal     Substantial
# 20170724X70559                 Lake Travis       Non-Fatal     Substantial
# 20001214X37681                    UNALASKA       Non-Fatal     Substantial
# 20190515X71620           Edinburgh Airport       Non-Fatal         unknown
# 20030718X01154                     Wasilla       Non-Fatal     Substantial
# 20151221X34338               NEW JERUSALEM       Non-Fatal     Substantial
#
#                Registration.Number  ...    Engine.Type Purpose.of.flight  \
# Event.Id                            ...
# 20050811X01221              N915DJ  ...  Reciprocating          Personal
# 20001208X06951              N1117P  ...    Turbo Shaft             Ferry
# 20001212X20908              N6535E  ...  Reciprocating     Instructional
# 20060323X00339              N203DH  ...  Reciprocating     Instructional
# 20001207X04926               N932A  ...  Reciprocating          Personal
# 20170724X70559              N3119D  ...  Reciprocating    Other Work Use
# 20001214X37681              N674MA  ...      Turbo Fan           Unknown
# 20190515X71620              C-GMCP  ...            NaN           unknown
# 20030718X01154              N7699K  ...  Reciprocating          Personal
# 20151221X34338               N35KF  ...  Reciprocating          Personal
#
#                Total.Fatal.Injuries  Total.Serious.Injuries  \
# Event.Id
# 20050811X01221                  0.0                     0.0
# 20001208X06951                  0.0                     2.0
# 20001212X20908                  0.0                     0.0
# 20060323X00339                  0.0                     0.0
# 20001207X04926                  0.0                     0.0
# 20170724X70559                  0.0                     2.0
# 20001214X37681                  0.0                     0.0
# 20190515X71620                  0.0                     0.0
# 20030718X01154                  0.0                     0.0
# 20151221X34338                  0.0                     0.0
#
#                Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Id
# 20050811X01221                  0.0             1.0                VMC
# 20001208X06951                  0.0             0.0                VMC
# 20001212X20908                  0.0             2.0                VMC
# 20060323X00339                  0.0             2.0                VMC
# 20001207X04926                  0.0             1.0                VMC
# 20170724X70559                  0.0             1.0                VMC
# 20001214X37681                  1.0            20.0                VMC
# 20190515X71620                  0.0             2.0            unknown
# 20030718X01154                  0.0             2.0                VMC
# 20151221X34338                  0.0             1.0                VMC
#
#                 Broad.phase.of.flight  \
# Event.Id
# 20050811X01221                   Taxi
# 20001208X06951                unknown
# 20001212X20908                Landing
# 20060323X00339            Maneuvering
# 20001207X04926               Standing
# 20170724X70559                unknown
# 20001214X37681               Approach
# 20190515X71620                unknown
# 20030718X01154                Landing
# 20151221X34338                unknown
#
#                                                     Report.Status  \
# Event.Id
# 20050811X01221                                     Probable Cause
# 20001208X06951                                            Foreign
# 20001212X20908                                     Probable Cause
# 20060323X00339                                     Probable Cause
# 20001207X04926                                     Probable Cause
# 20170724X70559  The pilot's improper decision to attempt to ta...
# 20001214X37681                                     Probable Cause
# 20190515X71620                                            unknown
# 20030718X01154                                     Probable Cause
# 20151221X34338  The pilot's failure to maintain pitch control ...
#
#                 Publication.Date
# Event.Id
# 20050811X01221        29-11-2006
# 20001208X06951        25-10-1996
# 20001212X20908        02-03-2001
# 20060323X00339        31-10-2006
# 20001207X04926        14-02-1996
# 20170724X70559        25-09-2020
# 20001214X37681           unknown
# 20190515X71620        26-09-2020
# 20030718X01154        25-11-2003
# 20151221X34338        25-09-2020
#
# [10 rows x 24 columns]

# %% [markdown]
# ### 4.3 Checking for Duplicates

# %%
# checking for duplicates

duplicates = aviation_data[aviation_data.duplicated()]
print(len(duplicates))
duplicates.head()
# Out:
# 0
# Empty DataFrame
# Columns: [Investigation.Type, Accident.Number, Event.Date, Location, Country, Airport.Code, Airport.Name, Injury.Severity, Aircraft.damage, Registration.Number, Make, Model, Amateur.Built, Number.of.Engines, Engine.Type, Purpose.of.flight, Total.Fatal.Injuries, Total.Serious.Injuries, Total.Minor.Injuries, Total.Uninjured, Weather.Condition, Broad.phase.of.flight, Report.Status, Publication.Date]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### 4.4 Checking for extraneouse values

# %%
for col in aviation_data.columns:
    print(col, '\n', aviation_data[col].value_counts(normalize=True).head(), '\n\n')
# Out:
# Investigation.Type
#  Investigation.Type
# Accident    0.956418
# Incident    0.043582
# Name: proportion, dtype: float64
#
#
# Accident.Number
#  Accident.Number
# CEN22LA149    0.000022
# WPR23LA041    0.000022
# WPR23LA045    0.000022
# DCA22WA214    0.000022
# DCA22WA089    0.000022
# Name: proportion, dtype: float64
#
#
# Event.Date
#  Event.Date
# 1984-06-30    0.000281
# 1982-05-16    0.000281
# 2000-07-08    0.000281
# 1983-08-05    0.000270
# 1984-08-25    0.000270
# Name: proportion, dtype: float64
#
#
# Location
#  Location
# ANCHORAGE, AK      0.004882
# MIAMI, FL          0.002250
# ALBUQUERQUE, NM    0.002205
# HOUSTON, TX        0.002171
# CHICAGO, IL        0.002070
# Name: proportion, dtype: float64
#
#
# Country
#  Country
# United States     0.925289
# Brazil            0.004207
# Canada            0.004039
# Mexico            0.004027
# United Kingdom    0.003870
# Name: proportion, dtype: float64
#
#
# Airport.Code
#  Airport.Code
# unknown    0.436016
# NONE       0.016740
# PVT        0.005456
# APA        0.001800
# ORD        0.001676
# Name: proportion, dtype: float64
#
#
# Airport.Name
#  Airport.Name
# unknown             0.407081
# Private             0.002700
# PRIVATE             0.002520
# Private Airstrip    0.001721
# NONE                0.001642
# Name: proportion, dtype: float64
#
#
# Injury.Severity
#  Injury.Severity
# Non-Fatal    0.757765
# Fatal(1)     0.069379
# Fatal        0.059197
# Fatal(2)     0.041749
# Incident     0.024964
# Name: proportion, dtype: float64
#
#
# Aircraft.damage
#  Aircraft.damage
# Substantial    0.721664
# Destroyed      0.209508
# unknown        0.035932
# Minor          0.031556
# Unknown        0.001339
# Name: proportion, dtype: float64
#
#
# Registration.Number
#  Registration.Number
# unknown    0.015615
# NONE       0.003870
# UNREG      0.001417
# UNK        0.000146
# USAF       0.000101
# Name: proportion, dtype: float64
#
#
# Make
#  Make
# Cessna    0.250053
# Piper     0.135326
# CESSNA    0.055372
# Beech     0.048712
# PIPER     0.031961
# Name: proportion, dtype: float64
#
#
# Model
#  Model
# 152          0.026629
# 172          0.019755
# 172N         0.013095
# PA-28-140    0.010485
# 150          0.009326
# Name: proportion, dtype: float64
#
#
# Amateur.Built
#  Amateur.Built
# No         0.903509
# Yes        0.095344
# unknown    0.001147
# Name: proportion, dtype: float64
#
#
# Number.of.Engines
#  Number.of.Engines
# 1.0    0.782797
# 2.0    0.124639
# 0.0    0.082237
# 3.0    0.005434
# 4.0    0.004849
# Name: proportion, dtype: float64
#
#
# Engine.Type
#  Engine.Type
# Reciprocating    0.850073
# Turbo Shaft      0.044124
# Turbo Prop       0.041458
# Turbo Fan        0.030333
# Unknown          0.025075
# Name: proportion, dtype: float64
#
#
# Purpose.of.flight
#  Purpose.of.flight
# Personal              0.556289
# Instructional         0.119261
# Unknown               0.076522
# unknown               0.069660
# Aerial Application    0.053010
# Name: proportion, dtype: float64
#
#
# Total.Fatal.Injuries
#  Total.Fatal.Injuries
# 0.0    0.799604
# 1.0    0.099934
# 2.0    0.058196
# 3.0    0.017876
# 4.0    0.012409
# Name: proportion, dtype: float64
#
#
# Total.Serious.Injuries
#  Total.Serious.Injuries
# 0.0    0.852738
# 1.0    0.102656
# 2.0    0.031669
# 3.0    0.007076
# 4.0    0.002902
# Name: proportion, dtype: float64
#
#
# Total.Minor.Injuries
#  Total.Minor.Injuries
# 0.0    0.825603
# 1.0    0.116100
# 2.0    0.040230
# 3.0    0.008820
# 4.0    0.004185
# Name: proportion, dtype: float64
#
#
# Total.Uninjured
#  Total.Uninjured
# 0.0    0.402648
# 1.0    0.282386
# 2.0    0.179865
# 3.0    0.048521
# 4.0    0.029947
# Name: proportion, dtype: float64
#
#
# Weather.Condition
#  Weather.Condition
# VMC        0.869658
# IMC        0.067230
# unknown    0.050535
# UNK        0.009630
# Unk        0.002947
# Name: proportion, dtype: float64
#
#
# Broad.phase.of.flight
#  Broad.phase.of.flight
# unknown        0.305606
# Landing        0.173565
# Takeoff        0.140546
# Cruise         0.115526
# Maneuvering    0.091620
# Name: proportion, dtype: float64
#
#
# Report.Status
#  Report.Status
# Probable Cause    0.694732
# unknown           0.071820
# Foreign           0.022489
# <br /><br />      0.001879
# Factual           0.001631
# Name: proportion, dtype: float64
#
#
# Publication.Date
#  Publication.Date
# 25-09-2020    0.191464
# unknown       0.154924
# 26-09-2020    0.019901
# 03-11-2020    0.012994
# 31-03-1993    0.005085
# Name: proportion, dtype: float64

# %%
# confirming if there are still missing values in the data
aviation_data.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Engine.Type               7096
# Investigation.Type           0
# Accident.Number              0
# Report.Status                0
# Broad.phase.of.flight        0
# Weather.Condition            0
# Total.Uninjured              0
# Total.Minor.Injuries         0
# Total.Serious.Injuries       0
# Total.Fatal.Injuries         0
# dtype: int64

# %% [markdown]
# There are 7096 missing values in Engine. Type columns.

# %%
# Handling the remaining missing values in the Engine.Type column

aviation_data['Engine.Type']= aviation_data['Engine.Type'].fillna("Unknown")
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      unknown      unknown
# 20001218X45447   BRIDGEPORT, CA  United States      unknown      unknown
# 20061025X01555    Saltville, VA  United States      unknown      unknown
# 20001218X45448       EUREKA, CA  United States      unknown      unknown
# 20041105X01764       Canton, OH  United States      unknown      unknown
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States      unknown      unknown
# 20221227106494      Hampton, NH  United States      unknown      unknown
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States      unknown      unknown
# 20221230106513       Athens, GA  United States      unknown      unknown
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor         unknown              N1867H  ...
# 20221227106494         unknown         unknown              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498         unknown         unknown              N210CU  ...
# 20221230106513           Minor         unknown              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764        Unknown          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491        Unknown          Personal                  0.0
# 20221227106494        Unknown           unknown                  0.0
# 20221227106497        Unknown          Personal                  0.0
# 20221227106498        Unknown          Personal                  0.0
# 20221230106513        Unknown          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     0.0                  0.0             0.0
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  0.0             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491            unknown                unknown         unknown
# 20221227106494            unknown                unknown         unknown
# 20221227106497                VMC                unknown         unknown
# 20221227106498            unknown                unknown         unknown
# 20221230106513            unknown                unknown         unknown
#
#                 Publication.Date
# Event.Id
# 20001218X45444           unknown
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494           unknown
# 20221227106497        27-12-2022
# 20221227106498           unknown
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
aviation_data.isnull().sum().sort_values(ascending=False)
# Out:
# Investigation.Type        0
# Accident.Number           0
# Report.Status             0
# Broad.phase.of.flight     0
# Weather.Condition         0
# Total.Uninjured           0
# Total.Minor.Injuries      0
# Total.Serious.Injuries    0
# Total.Fatal.Injuries      0
# Purpose.of.flight         0
# Engine.Type               0
# Number.of.Engines         0
# Amateur.Built             0
# Model                     0
# Make                      0
# Registration.Number       0
# Aircraft.damage           0
# Injury.Severity           0
# Airport.Name              0
# Airport.Code              0
# Country                   0
# Location                  0
# Event.Date                0
# Publication.Date          0
# dtype: int64

# %%
# saving cleaned data as a csv file
aviation_data.to_csv("cleaned_data.csv", index=False)

# %% [markdown]
# ### Carrying out standardization on vital columns relevant in our analysis
#
# These columns include Make, mode, location and injury severity

# %%
# Converting to Lower/uppercase
aviation_data["Make"] = aviation_data["Make"].str.upper()
aviation_data["Model"] = aviation_data["Model"].str.upper()
aviation_data["Location"] = aviation_data["Location"].str.title()  # Keep location readable
aviation_data["Injury.Severity"] = aviation_data["Injury.Severity"].str.title()

# %%
# Stripping Extra whitespace
aviation_data["Make"] = aviation_data["Make"].str.strip()
aviation_data["Model"] = aviation_data["Model"].str.strip()
aviation_data["Location"] = aviation_data["Location"].str.strip()

# %%
# Fixing typos
aviation_data["Make"] = aviation_data["Make"].replace({
    "CESSNA ": "CESSNA",
    "BOEING  ": "BOEING",
    "CESSNA AIRCRAFT": "CESSNA"
})

# %%
aviation_data["Country"].value_counts()
# Out:
# Country
# United States                       82248
# Brazil                                374
# Canada                                359
# Mexico                                358
# United Kingdom                        344
#                                     ...
# Seychelles                              1
# Palau                                   1
# Libya                                   1
# Saint Vincent and the Grenadines        1
# Turks and Caicos Islands                1
# Name: count, Length: 220, dtype: int64

# %% [markdown]
# Since majority of the cases are in the united states, I only going to concentrate on the united states.

# %%
# extracting united states data for analysis
us_data = aviation_data[aviation_data["Country"] == "United States"]
us_data.head()
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  Moose Creek, Id  United States      unknown      unknown
# 20001218X45447   Bridgeport, Ca  United States      unknown      unknown
# 20061025X01555    Saltville, Va  United States      unknown      unknown
# 20001218X45448       Eureka, Ca  United States      unknown      unknown
# 20041105X01764       Canton, Oh  United States      unknown      unknown
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764        Unknown          Personal                  1.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     0.0                  0.0             0.0
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  0.0             0.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
#
#                 Publication.Date
# Event.Id
# 20001218X45444           unknown
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
#
# [5 rows x 24 columns]

# %%
# checking the dimensions of us_data i.e rows and columns
us_data.shape
# Out:
# (82248, 24)

# %%
# checking for missing values and data types
us_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82248 entries, 20001218X45444 to 20221230106513
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      82248 non-null  object
#  1   Accident.Number         82248 non-null  object
#  2   Event.Date              82248 non-null  object
#  3   Location                82248 non-null  object
#  4   Country                 82248 non-null  object
#  5   Airport.Code            82248 non-null  object
#  6   Airport.Name            82248 non-null  object
#  7   Injury.Severity         82248 non-null  object
#  8   Aircraft.damage         82248 non-null  object
#  9   Registration.Number     82248 non-null  object
#  10  Make                    82248 non-null  object
#  11  Model                   82248 non-null  object
#  12  Amateur.Built           82248 non-null  object
#  13  Number.of.Engines       82248 non-null  float64
#  14  Engine.Type             82248 non-null  object
#  15  Purpose.of.flight       82248 non-null  object
#  16  Total.Fatal.Injuries    82248 non-null  float64
#  17  Total.Serious.Injuries  82248 non-null  float64
#  18  Total.Minor.Injuries    82248 non-null  float64
#  19  Total.Uninjured         82248 non-null  float64
#  20  Weather.Condition       82248 non-null  object
#  21  Broad.phase.of.flight   82248 non-null  object
#  22  Report.Status           82248 non-null  object
#  23  Publication.Date        82248 non-null  object
# dtypes: float64(5), object(19)
# memory usage: 15.7+ MB

# %%
us_data.to_csv("United_States_data.csv", index=False)

# %% [markdown]
# ## United States Data Analysis

# %% [markdown]
# ### 1.1 Univariate Analysis
#
# Answers: Which aircraft models have the lowest number of reported accidents in the dataset?

# %%
# Count the number of accidents by Aircraft Make
aircraft_counts = us_data['Make'].value_counts().head(50)
aircraft_counts
# Out:
# Make
# CESSNA                            25854
# PIPER                             14168
# BEECH                              5059
# BELL                               2285
# BOEING                             1485
# MOONEY                             1293
# GRUMMAN                            1142
# BELLANCA                           1040
# ROBINSON                            919
# HUGHES                              874
# SCHWEIZER                           744
# AIR TRACTOR                         644
# AERONCA                             635
# MAULE                               577
# CHAMPION                            514
# MCDONNELL DOUGLAS                   463
# STINSON                             439
# LUSCOMBE                            413
# AERO COMMANDER                      397
# TAYLORCRAFT                         382
# DE HAVILLAND                        377
# NORTH AMERICAN                      373
# AEROSPATIALE                        348
# HILLER                              344
# ROCKWELL                            337
# ENSTROM                             285
# ROBINSON HELICOPTER                 228
# DOUGLAS                             224
# GRUMMAN AMERICAN                    223
# AIR TRACTOR INC                     218
# AYRES                               216
# CIRRUS DESIGN CORP                  206
# EUROCOPTER                          189
# ROBINSON HELICOPTER COMPANY         181
# SIKORSKY                            162
# ERCOUPE (ENG & RESEARCH CORP.)      160
# EMBRAER                             158
# SWEARINGEN                          156
# BALLOON WORKS                       147
# PITTS                               145
# SCHLEICHER                          144
# LAKE                                142
# FAIRCHILD                           142
# WACO                                141
# AVIAT                               137
# MITSUBISHI                          135
# LET                                 132
# GRUMMAN-SCHWEIZER                   127
# BURKHART GROB                       121
# VANS                                112
# Name: count, dtype: int64

# %%
# visualizing accident counts by make
plt.figure(figsize=(12,6))
sns.barplot(x=aircraft_counts.values, y=aircraft_counts.index)
plt.title("Top 10 Aircraft Makes Involved in Accidents")
plt.xlabel("Number of Accidents")
plt.ylabel("Aircraft Make")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 Univariate Analysis
#
# Answers: Is there a relationship between engine builder and accident frequency?

# %%
# Count accidents by amateur-built status
amateur_counts = aviation_data['Amateur.Built'].value_counts()
amateur_counts
# Out:
# Amateur.Built
# No         80312
# Yes         8475
# unknown      102
# Name: count, dtype: int64

# %%
# visualization
plt.figure(figsize=(6,6))
sns.barplot(x=amateur_counts.index, y=amateur_counts.values)
plt.title("Accident Frequency by Aircraft Build Type")
plt.xlabel("Amateur Builders")
plt.ylabel("Number of Accidents")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis
#
# Answers: What is the accident rate per aircraft model, considering how often each model appears?

# %%
model_counts = aviation_data.groupby(['Make', 'Model']).size().reset_index(name='Accident_Count')
model_counts
# Out:
#                            Make                Model  Accident_Count
# 0      107.5 FLYING CORPORATION    ONE DESIGN DR 107               1
# 1                          1200                 G103               1
# 2                     177MF LLC       PITTS MODEL 12               1
# 3              1977 COLFER-CHAN        STEEN SKYBOLT               1
# 4                    1ST FTR GP       FOCKE-WULF 190               1
# ...                         ...                  ...             ...
# 18278             ZUBAIR S KHAN                RAVEN               1
# 18279            ZUBER THOMAS P  ZUBER SUPER DRIFTER               1
# 18280                  ZUKOWSKI          EAA BIPLANE               1
# 18281                     ZWART        KIT FOX VIXEN               1
# 18282          ZWICKER MURRAY R              GLASTAR               1
#
# [18283 rows x 3 columns]

# %%
total_accidents = aviation_data.shape[0]
total_accidents
# Out:
# 88889

# %%
model_counts['Accident_Rate_Percent'] = (model_counts['Accident_Count'] / total_accidents) * 100
model_counts
# Out:
#                            Make                Model  Accident_Count  \
# 0      107.5 FLYING CORPORATION    ONE DESIGN DR 107               1
# 1                          1200                 G103               1
# 2                     177MF LLC       PITTS MODEL 12               1
# 3              1977 COLFER-CHAN        STEEN SKYBOLT               1
# 4                    1ST FTR GP       FOCKE-WULF 190               1
# ...                         ...                  ...             ...
# 18278             ZUBAIR S KHAN                RAVEN               1
# 18279            ZUBER THOMAS P  ZUBER SUPER DRIFTER               1
# 18280                  ZUKOWSKI          EAA BIPLANE               1
# 18281                     ZWART        KIT FOX VIXEN               1
# 18282          ZWICKER MURRAY R              GLASTAR               1
#
#        Accident_Rate_Percent
# 0                   0.001125
# 1                   0.001125
# 2                   0.001125
# 3                   0.001125
# 4                   0.001125
# ...                      ...
# 18278               0.001125
# 18279               0.001125
# 18280               0.001125
# 18281               0.001125
# 18282               0.001125
#
# [18283 rows x 4 columns]

# %%
top_models_by_rate = model_counts.sort_values('Accident_Rate_Percent', ascending=False).head(10)
top_models_by_rate
# Out:
#          Make      Model  Accident_Count  Accident_Rate_Percent
# 4617   CESSNA        152            2366               2.661747
# 4641   CESSNA        172            1754               1.973248
# 4692   CESSNA       172N            1163               1.308373
# 13410   PIPER  PA-28-140             932               1.048499
# 4590   CESSNA        150             829               0.932624
# 4690   CESSNA       172M             798               0.897749
# 4695   CESSNA       172P             689               0.775124
# 4749   CESSNA        182             659               0.741374
# 4725   CESSNA        180             621               0.698624
# 4616   CESSNA       150M             585               0.658124

# %% [markdown]
# ### Multivariate Analysis
#
# Answers: Among aircraft with high accident frequency, what are the common engine manufacturers and engine models?

# %%
# Get top accident-prone aircraft
risky_aircraft = us_data['Make'].value_counts().head(10).index
risky_aircraft
# Out:
# Index(['CESSNA', 'PIPER', 'BEECH', 'BELL', 'BOEING', 'MOONEY', 'GRUMMAN',
#        'BELLANCA', 'ROBINSON', 'HUGHES'],
#       dtype='object', name='Make')

# %%
# Filter and group
engine_stats = us_data[us_data['Make'].isin(risky_aircraft)]
engine_grouped = engine_stats.groupby(['Make', 'Engine.Type'])['Accident.Number'].count().reset_index()
engine_grouped
# Out:
#         Make    Engine.Type  Accident.Number
# 0      BEECH  Reciprocating             4339
# 1      BEECH      Turbo Fan               10
# 2      BEECH      Turbo Jet                4
# 3      BEECH     Turbo Prop              565
# 4      BEECH    Turbo Shaft                2
# 5      BEECH        Unknown              139
# 6       BELL  Reciprocating              668
# 7       BELL      Turbo Fan                1
# 8       BELL      Turbo Jet                7
# 9       BELL     Turbo Prop                3
# 10      BELL    Turbo Shaft             1523
# 11      BELL        Unknown               83
# 12  BELLANCA  Reciprocating             1023
# 13  BELLANCA        Unknown               17
# 14    BOEING  Reciprocating              359
# 15    BOEING      Turbo Fan              820
# 16    BOEING      Turbo Jet              174
# 17    BOEING     Turbo Prop                4
# 18    BOEING    Turbo Shaft                7
# 19    BOEING        Unknown              121
# 20    CESSNA  Reciprocating            24836
# 21    CESSNA      Turbo Fan              163
# 22    CESSNA      Turbo Jet               46
# 23    CESSNA     Turbo Prop              299
# 24    CESSNA    Turbo Shaft                1
# 25    CESSNA            UNK                1
# 26    CESSNA        Unknown              508
# 27   GRUMMAN  Reciprocating             1055
# 28   GRUMMAN      Turbo Fan                3
# 29   GRUMMAN      Turbo Jet                6
# 30   GRUMMAN     Turbo Prop               67
# 31   GRUMMAN        Unknown               11
# 32    HUGHES  Reciprocating              411
# 33    HUGHES      Turbo Jet                1
# 34    HUGHES     Turbo Prop                3
# 35    HUGHES    Turbo Shaft              442
# 36    HUGHES        Unknown               17
# 37    MOONEY  Reciprocating             1263
# 38    MOONEY        Unknown               30
# 39     PIPER  Reciprocating            13667
# 40     PIPER     Turbo Prop              176
# 41     PIPER    Turbo Shaft                1
# 42     PIPER        Unknown              324
# 43  ROBINSON  Reciprocating              901
# 44  ROBINSON    Turbo Shaft                9
# 45  ROBINSON        Unknown                9

# %%
plt.figure(figsize=(14,8))
sns.barplot(data=engine_grouped, x='Accident.Number', y='Make', hue='Engine.Type')
plt.title("Engine Builders for Top 10 Accident-Prone Aircraft")
plt.xlabel("Number of Accidents")
plt.ylabel("Aircraft Make")
plt.legend(title="Engine Manufacturer")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
# 1. Few aircrafs(e.g VANS,KLOTZ,JOHANNES-ROBERT) have less number of accidents. This could mean that maybe there are a few such aircraft flying. Alternatively, that could mean they have extremely strict management rules in selecting and training pilots.
# 2. Most of the accidents involved professionally built engine(over 80,000), while a significantly lower number that are amatuer built(below 10,000) are involved in accidents.
# 3. Aircaft models(e.g CESSNA 152, CESSNA 172,CESSNA 172N) have a very high rate of accidents i.e 2.67%,1.97% and 1.31% repectively. This could mean they are popular brands that are loved by a lot of people but pose significant risks.
# 4. Reciprocating engines are found in most of the top aircraft involved in accidents.

# %% [markdown]
# ## Recommendations
#
# 1. Avoid models such as CESSNA 152, which have high crash rates. Make such as VANS, LET are recommended.
# 2. Amateur-built models have low accident rates.
# 3. Choose aircraft with low fatality rates such as VANS.
# 4. Avoid models with reciprocating engines. Models such as Turbo prop, Turbo Shaft have been proven to pose less crash risk.
