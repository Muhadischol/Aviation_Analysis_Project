# %% [markdown]
# # Aviation Accidents Analysis

# %% [markdown]
# ## 1. Overview
#
# A company I am working with is planning to diversify its portfolio by exploring new areas, particularly the aviation industry. The leadership is interested in the risks associated with aircraft operations, mainly safety and reliability. It is on that background that as a senior data scientist in the company that the management tusked me with the responsibility of carrying out data analysis to assist the management in making informed investment decisions to determine which aircraft presents the lowest operational risk.

# %% [markdown]
# ## 2. Business Understanding
# To find out the safest and most reliable aircraft for the company to purchase based on an analysis of accident and incident data collected over the years. Therefore, the company wants to:
# * Minimize accident frequency
# * low fetality count

# %% [markdown]
# ## 3. Data Science Understanding
# Analyze accident data collected over the years to establish which aircraft has the lowest risk by using risk indicators such as accident frequency, fatality rate, and severity of injuries.
# This will involve the following analysis:
# * Data exploration
# * Data Cleaning
# * Grouping aircraft by make and model
# * Calculating the safety matrix per aircraft type
# * Visualizing patterns of high-risk and low-risk aircrafts

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Loading accident data to the notebook
aviation_data = pd.read_csv("../Data/AviationData.csv", index_col = 0, encoding = "latin1", low_memory = False)

# %% [markdown]
# ### 3.1 exploring data

# %%
aviation_data.head() # checking the first five rows of the dataframe
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
#
#                        Location        Country   Latitude   Longitude  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States        NaN         NaN
# 20001218X45447   BRIDGEPORT, CA  United States        NaN         NaN
# 20061025X01555    Saltville, VA  United States  36.922223  -81.878056
# 20001218X45448       EUREKA, CA  United States        NaN         NaN
# 20041105X01764       Canton, OH  United States        NaN         NaN
#
#                Airport.Code Airport.Name Injury.Severity  ...  \
# Event.Id                                                  ...
# 20001218X45444          NaN          NaN        Fatal(2)  ...
# 20001218X45447          NaN          NaN        Fatal(4)  ...
# 20061025X01555          NaN          NaN        Fatal(3)  ...
# 20001218X45448          NaN          NaN        Fatal(2)  ...
# 20041105X01764          NaN          NaN        Fatal(1)  ...
#
#                Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444          Personal         NaN                  2.0
# 20001218X45447          Personal         NaN                  4.0
# 20061025X01555          Personal         NaN                  3.0
# 20001218X45448          Personal         NaN                  2.0
# 20041105X01764          Personal         NaN                  1.0
#
#                Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                    0.0                  0.0             0.0
# 20001218X45447                    0.0                  0.0             0.0
# 20061025X01555                    NaN                  NaN             NaN
# 20001218X45448                    0.0                  0.0             0.0
# 20041105X01764                    2.0                  NaN             0.0
#
#                 Weather.Condition Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                Cruise  Probable Cause
# 20001218X45447                UNK               Unknown  Probable Cause
# 20061025X01555                IMC                Cruise  Probable Cause
# 20001218X45448                IMC                Cruise  Probable Cause
# 20041105X01764                VMC              Approach  Probable Cause
#
#                Publication.Date
# Event.Id
# 20001218X45444              NaN
# 20001218X45447       19-09-1996
# 20061025X01555       26-02-2007
# 20001218X45448       12-09-2000
# 20041105X01764       16-04-1980
#
# [5 rows x 30 columns]

# %%
aviation_data.tail() # chwcking the last five rows of the dataframe
# Out:
#                Investigation.Type Accident.Number  Event.Date       Location  \
# Event.Id
# 20221227106491           Accident      ERA23LA093  2022-12-26  Annapolis, MD
# 20221227106494           Accident      ERA23LA095  2022-12-26    Hampton, NH
# 20221227106497           Accident      WPR23LA075  2022-12-26     Payson, AZ
# 20221227106498           Accident      WPR23LA076  2022-12-26     Morgan, UT
# 20221230106513           Accident      ERA23LA097  2022-12-29     Athens, GA
#
#                       Country Latitude Longitude Airport.Code Airport.Name  \
# Event.Id
# 20221227106491  United States      NaN       NaN          NaN          NaN
# 20221227106494  United States      NaN       NaN          NaN          NaN
# 20221227106497  United States  341525N  1112021W          PAN       PAYSON
# 20221227106498  United States      NaN       NaN          NaN          NaN
# 20221230106513  United States      NaN       NaN          NaN          NaN
#
#                Injury.Severity  ... Purpose.of.flight         Air.carrier  \
# Event.Id                        ...
# 20221227106491           Minor  ...          Personal                 NaN
# 20221227106494             NaN  ...               NaN                 NaN
# 20221227106497       Non-Fatal  ...          Personal                 NaN
# 20221227106498             NaN  ...          Personal  MC CESSNA 210N LLC
# 20221230106513           Minor  ...          Personal                 NaN
#
#                Total.Fatal.Injuries Total.Serious.Injuries  \
# Event.Id
# 20221227106491                  0.0                    1.0
# 20221227106494                  0.0                    0.0
# 20221227106497                  0.0                    0.0
# 20221227106498                  0.0                    0.0
# 20221230106513                  0.0                    1.0
#
#                Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Id
# 20221227106491                  0.0             0.0                NaN
# 20221227106494                  0.0             0.0                NaN
# 20221227106497                  0.0             1.0                VMC
# 20221227106498                  0.0             0.0                NaN
# 20221230106513                  0.0             1.0                NaN
#
#                Broad.phase.of.flight Report.Status Publication.Date
# Event.Id
# 20221227106491                   NaN           NaN       29-12-2022
# 20221227106494                   NaN           NaN              NaN
# 20221227106497                   NaN           NaN       27-12-2022
# 20221227106498                   NaN           NaN              NaN
# 20221230106513                   NaN           NaN       30-12-2022
#
# [5 rows x 30 columns]

# %%
aviation_data.info() # getting concise information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Latitude                34382 non-null  object
#  6   Longitude               34373 non-null  object
#  7   Airport.Code            50132 non-null  object
#  8   Airport.Name            52704 non-null  object
#  9   Injury.Severity         87889 non-null  object
#  10  Aircraft.damage         85695 non-null  object
#  11  Aircraft.Category       32287 non-null  object
#  12  Registration.Number     87507 non-null  object
#  13  Make                    88826 non-null  object
#  14  Model                   88797 non-null  object
#  15  Amateur.Built           88787 non-null  object
#  16  Number.of.Engines       82805 non-null  float64
#  17  Engine.Type             81793 non-null  object
#  18  FAR.Description         32023 non-null  object
#  19  Schedule                12582 non-null  object
#  20  Purpose.of.flight       82697 non-null  object
#  21  Air.carrier             16648 non-null  object
#  22  Total.Fatal.Injuries    77488 non-null  float64
#  23  Total.Serious.Injuries  76379 non-null  float64
#  24  Total.Minor.Injuries    76956 non-null  float64
#  25  Total.Uninjured         82977 non-null  float64
#  26  Weather.Condition       84397 non-null  object
#  27  Broad.phase.of.flight   61724 non-null  object
#  28  Report.Status           82505 non-null  object
#  29  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(25)
# memory usage: 21.0+ MB

# %% [markdown]
# All the columns have missing values except the first three.

# %%
aviation_data.shape # checking the dataframe dimensions, i.e number of rows and cloumns in the dataframe.
# Out:
# (88889, 30)

# %% [markdown]
# Dataset contains 88,889 rows and 30 columns.

# %% [markdown]
# ## 4. Data Preparation and cleaning

# %% [markdown]
# ### 4.1 Checking for missing values

# %%
aviation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Latitude                34382 non-null  object
#  6   Longitude               34373 non-null  object
#  7   Airport.Code            50132 non-null  object
#  8   Airport.Name            52704 non-null  object
#  9   Injury.Severity         87889 non-null  object
#  10  Aircraft.damage         85695 non-null  object
#  11  Aircraft.Category       32287 non-null  object
#  12  Registration.Number     87507 non-null  object
#  13  Make                    88826 non-null  object
#  14  Model                   88797 non-null  object
#  15  Amateur.Built           88787 non-null  object
#  16  Number.of.Engines       82805 non-null  float64
#  17  Engine.Type             81793 non-null  object
#  18  FAR.Description         32023 non-null  object
#  19  Schedule                12582 non-null  object
#  20  Purpose.of.flight       82697 non-null  object
#  21  Air.carrier             16648 non-null  object
#  22  Total.Fatal.Injuries    77488 non-null  float64
#  23  Total.Serious.Injuries  76379 non-null  float64
#  24  Total.Minor.Injuries    76956 non-null  float64
#  25  Total.Uninjured         82977 non-null  float64
#  26  Weather.Condition       84397 non-null  object
#  27  Broad.phase.of.flight   61724 non-null  object
#  28  Report.Status           82505 non-null  object
#  29  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(25)
# memory usage: 21.0+ MB

# %%
missing_values_percentage= aviation_data.isnull().mean().sort_values(ascending = False) * 100
missing_values_percentage
# Out:
# Schedule                  85.845268
# Air.carrier               81.271023
# FAR.Description           63.974170
# Aircraft.Category         63.677170
# Longitude                 61.330423
# Latitude                  61.320298
# Airport.Code              43.601570
# Airport.Name              40.708074
# Broad.phase.of.flight     30.560587
# Publication.Date          15.492356
# Total.Serious.Injuries    14.073732
# Total.Minor.Injuries      13.424608
# Total.Fatal.Injuries      12.826109
# Engine.Type                7.982990
# Report.Status              7.181991
# Purpose.of.flight          6.965991
# Number.of.Engines          6.844491
# Total.Uninjured            6.650992
# Weather.Condition          5.053494
# Aircraft.damage            3.593246
# Registration.Number        1.554748
# Injury.Severity            1.124999
# Country                    0.254250
# Amateur.Built              0.114750
# Model                      0.103500
# Make                       0.070875
# Location                   0.058500
# Accident.Number            0.000000
# Event.Date                 0.000000
# Investigation.Type         0.000000
# dtype: float64

# %%
# columns with more than 60 percent missing values
columns_to_drop = missing_values_percentage.head(6) 
columns_to_drop
# Out:
# Schedule             85.845268
# Air.carrier          81.271023
# FAR.Description      63.974170
# Aircraft.Category    63.677170
# Longitude            61.330423
# Latitude             61.320298
# dtype: float64

# %%
# Dropping columns that have more than 60 percent missing values
aviation_data = aviation_data.drop(columns= columns_to_drop.index)
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States          NaN          NaN
# 20001218X45447   BRIDGEPORT, CA  United States          NaN          NaN
# 20061025X01555    Saltville, VA  United States          NaN          NaN
# 20001218X45448       EUREKA, CA  United States          NaN          NaN
# 20041105X01764       Canton, OH  United States          NaN          NaN
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States          NaN          NaN
# 20221227106494      Hampton, NH  United States          NaN          NaN
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States          NaN          NaN
# 20221230106513       Athens, GA  United States          NaN          NaN
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor             NaN              N1867H  ...
# 20221227106494             NaN             NaN              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498             NaN             NaN              N210CU  ...
# 20221230106513           Minor             NaN              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764            NaN          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491            NaN          Personal                  0.0
# 20221227106494            NaN               NaN                  0.0
# 20221227106497            NaN          Personal                  0.0
# 20221227106498            NaN          Personal                  0.0
# 20221230106513            NaN          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     NaN                  NaN             NaN
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  NaN             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491                NaN                    NaN             NaN
# 20221227106494                NaN                    NaN             NaN
# 20221227106497                VMC                    NaN             NaN
# 20221227106498                NaN                    NaN             NaN
# 20221230106513                NaN                    NaN             NaN
#
#                 Publication.Date
# Event.Id
# 20001218X45444               NaN
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494               NaN
# 20221227106497        27-12-2022
# 20221227106498               NaN
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
aviation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88889 entries, 20001218X45444 to 20221230106513
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Investigation.Type      88889 non-null  object
#  1   Accident.Number         88889 non-null  object
#  2   Event.Date              88889 non-null  object
#  3   Location                88837 non-null  object
#  4   Country                 88663 non-null  object
#  5   Airport.Code            50132 non-null  object
#  6   Airport.Name            52704 non-null  object
#  7   Injury.Severity         87889 non-null  object
#  8   Aircraft.damage         85695 non-null  object
#  9   Registration.Number     87507 non-null  object
#  10  Make                    88826 non-null  object
#  11  Model                   88797 non-null  object
#  12  Amateur.Built           88787 non-null  object
#  13  Number.of.Engines       82805 non-null  float64
#  14  Engine.Type             81793 non-null  object
#  15  Purpose.of.flight       82697 non-null  object
#  16  Total.Fatal.Injuries    77488 non-null  float64
#  17  Total.Serious.Injuries  76379 non-null  float64
#  18  Total.Minor.Injuries    76956 non-null  float64
#  19  Total.Uninjured         82977 non-null  float64
#  20  Weather.Condition       84397 non-null  object
#  21  Broad.phase.of.flight   61724 non-null  object
#  22  Report.Status           82505 non-null  object
#  23  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(19)
# memory usage: 17.0+ MB

# %% [markdown]
# ### 4.2 Filling the missing values

# %%
categorical_columns = ["Investigation.Type", "Accident.Number", "Event.Date", "Location", "Country", "Airport.Code", "Airport.Name", "Injury.Severity", "Aircraft.damage", "Registration.Number", "Make", "Model", "Amateur.Built", "Purpose.of.flight", "Weather.Condition", "Broad.phase.of.flight", "Report.Status","Publication.Date"]
categorical_columns
# Out:
# ['Investigation.Type',
#  'Accident.Number',
#  'Event.Date',
#  'Location',
#  'Country',
#  'Airport.Code',
#  'Airport.Name',
#  'Injury.Severity',
#  'Aircraft.damage',
#  'Registration.Number',
#  'Make',
#  'Model',
#  'Amateur.Built',
#  'Purpose.of.flight',
#  'Weather.Condition',
#  'Broad.phase.of.flight',
#  'Report.Status',
#  'Publication.Date']

# %%
aviation_data[categorical_columns] = aviation_data[categorical_columns].fillna("unknown")
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      unknown      unknown
# 20001218X45447   BRIDGEPORT, CA  United States      unknown      unknown
# 20061025X01555    Saltville, VA  United States      unknown      unknown
# 20001218X45448       EUREKA, CA  United States      unknown      unknown
# 20041105X01764       Canton, OH  United States      unknown      unknown
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States      unknown      unknown
# 20221227106494      Hampton, NH  United States      unknown      unknown
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States      unknown      unknown
# 20221230106513       Athens, GA  United States      unknown      unknown
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor         unknown              N1867H  ...
# 20221227106494         unknown         unknown              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498         unknown         unknown              N210CU  ...
# 20221230106513           Minor         unknown              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764            NaN          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491            NaN          Personal                  0.0
# 20221227106494            NaN           unknown                  0.0
# 20221227106497            NaN          Personal                  0.0
# 20221227106498            NaN          Personal                  0.0
# 20221230106513            NaN          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     NaN                  NaN             NaN
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  NaN             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491            unknown                unknown         unknown
# 20221227106494            unknown                unknown         unknown
# 20221227106497                VMC                unknown         unknown
# 20221227106498            unknown                unknown         unknown
# 20221230106513            unknown                unknown         unknown
#
#                 Publication.Date
# Event.Id
# 20001218X45444           unknown
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494           unknown
# 20221227106497        27-12-2022
# 20221227106498           unknown
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
aviation_data.sample(10)
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20170706X21348           Accident      WPR17LA143  2017-07-06
# 20001213X34347           Accident      SEA86LA186  1986-07-31
# 20010124X00353           Accident      ATL01LA024  2001-01-18
# 20020701X01015           Accident      NYC02LA122  2002-06-24
# 20001206X01427           Accident      ATL94LA112  1994-06-02
# 20001213X25450           Accident      DEN88FA097  1988-04-15
# 20001211X11023           Accident      CHI98LA351  1998-09-17
# 20001212X24451           Accident      DEN91LA003  1990-10-06
# 20160913X24155           Accident      GAA16CA482  2016-09-09
# 20140728X50351           Accident      CEN14CA392  2014-07-26
#
#                          Location        Country Airport.Code  \
# Event.Id
# 20170706X21348          Ronan, MT  United States      unknown
# 20001213X34347      HILLSBORO, OR  United States          HIO
# 20010124X00353  ST. AUGUSTINE, FL  United States          SGJ
# 20020701X01015      ELLINGTON, CT  United States          7B9
# 20001206X01427     SUMMERDALE, AL  United States         NONE
# 20001213X25450     DEER LODGE, MT  United States          385
# 20001211X11023        CHICAGO, IL  United States          ORD
# 20001212X24451     BERNALILLO, NM  United States         NONE
# 20160913X24155        Gulkana, AK  United States      unknown
# 20140728X50351         Caputa, SD  United States          XXX
#
#                      Airport.Name Injury.Severity Aircraft.damage  \
# Event.Id
# 20170706X21348            unknown       Non-Fatal     Substantial
# 20001213X34347          HILLSBORO       Non-Fatal     Substantial
# 20010124X00353      ST. AUGUSTINE       Non-Fatal     Substantial
# 20020701X01015  Ellington Airport       Non-Fatal     Substantial
# 20001206X01427             BONNER       Non-Fatal     Substantial
# 20001213X25450    DEER LODGE CITY        Fatal(2)       Destroyed
# 20001211X11023       O'HARE INT'L       Non-Fatal         unknown
# 20001212X24451            unknown        Fatal(2)       Destroyed
# 20160913X24155            unknown       Non-Fatal     Substantial
# 20140728X50351   Private Airstrip       Non-Fatal     Substantial
#
#                Registration.Number  ...    Engine.Type Purpose.of.flight  \
# Event.Id                            ...
# 20170706X21348              N442DR  ...  Reciprocating          Personal
# 20001213X34347              N1782X  ...  Reciprocating          Business
# 20010124X00353              N704ZF  ...  Reciprocating     Instructional
# 20020701X01015              N2516G  ...  Reciprocating    Other Work Use
# 20001206X01427              N53819  ...  Reciprocating           Unknown
# 20001213X25450              N13788  ...  Reciprocating          Personal
# 20001211X11023              N233RM  ...     Turbo Prop           Unknown
# 20001212X24451              N4062H  ...        Unknown          Personal
# 20160913X24155              N13833  ...  Reciprocating          Personal
# 20140728X50351              N5530K  ...  Reciprocating     Instructional
#
#                Total.Fatal.Injuries  Total.Serious.Injuries  \
# Event.Id
# 20170706X21348                  0.0                     1.0
# 20001213X34347                  0.0                     0.0
# 20010124X00353                  NaN                     NaN
# 20020701X01015                  NaN                     NaN
# 20001206X01427                  0.0                     0.0
# 20001213X25450                  2.0                     0.0
# 20001211X11023                  0.0                     1.0
# 20001212X24451                  2.0                     0.0
# 20160913X24155                  0.0                     0.0
# 20140728X50351                  0.0                     0.0
#
#                Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Id
# 20170706X21348                  1.0             0.0                VMC
# 20001213X34347                  0.0             3.0                VMC
# 20010124X00353                  NaN             1.0                IMC
# 20020701X01015                  NaN             1.0                VMC
# 20001206X01427                  0.0             1.0                VMC
# 20001213X25450                  0.0             0.0                VMC
# 20001211X11023                  0.0            15.0                VMC
# 20001212X24451                  0.0             0.0                VMC
# 20160913X24155                  0.0             1.0                VMC
# 20140728X50351                  0.0             2.0                VMC
#
#                 Broad.phase.of.flight  \
# Event.Id
# 20170706X21348                unknown
# 20001213X34347                Takeoff
# 20010124X00353                Landing
# 20020701X01015                Descent
# 20001206X01427                Takeoff
# 20001213X25450                Takeoff
# 20001211X11023               Approach
# 20001212X24451                 Cruise
# 20160913X24155                unknown
# 20140728X50351                unknown
#
#                                                     Report.Status  \
# Event.Id
# 20170706X21348  The pilot's failure to maintain adequate airsp...
# 20001213X34347                                     Probable Cause
# 20010124X00353                                     Probable Cause
# 20020701X01015                                     Probable Cause
# 20001206X01427                                     Probable Cause
# 20001213X25450                                     Probable Cause
# 20001211X11023                                     Probable Cause
# 20001212X24451                                     Probable Cause
# 20160913X24155  The pilots failure to maintain clearance from...
# 20140728X50351  The student pilot's improper takeoff procedure...
#
#                 Publication.Date
# Event.Id
# 20170706X21348        25-09-2020
# 20001213X34347           unknown
# 20010124X00353        30-07-2001
# 20020701X01015        08-04-2003
# 20001206X01427        25-04-1995
# 20001213X25450        28-02-1989
# 20001211X11023        11-02-2000
# 20001212X24451        09-11-1992
# 20160913X24155        25-09-2020
# 20140728X50351        25-09-2020
#
# [10 rows x 24 columns]

# %%
numericals_columns = ["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Uninjured", "Number.of.Engines"]
numericals_columns
# Out:
# ['Total.Fatal.Injuries',
#  'Total.Serious.Injuries',
#  'Total.Minor.Injuries',
#  'Total.Uninjured',
#  'Number.of.Engines']

# %%
aviation_data[numericals_columns] = aviation_data[numericals_columns].fillna(0)
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      unknown      unknown
# 20001218X45447   BRIDGEPORT, CA  United States      unknown      unknown
# 20061025X01555    Saltville, VA  United States      unknown      unknown
# 20001218X45448       EUREKA, CA  United States      unknown      unknown
# 20041105X01764       Canton, OH  United States      unknown      unknown
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States      unknown      unknown
# 20221227106494      Hampton, NH  United States      unknown      unknown
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States      unknown      unknown
# 20221230106513       Athens, GA  United States      unknown      unknown
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor         unknown              N1867H  ...
# 20221227106494         unknown         unknown              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498         unknown         unknown              N210CU  ...
# 20221230106513           Minor         unknown              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764            NaN          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491            NaN          Personal                  0.0
# 20221227106494            NaN           unknown                  0.0
# 20221227106497            NaN          Personal                  0.0
# 20221227106498            NaN          Personal                  0.0
# 20221230106513            NaN          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     0.0                  0.0             0.0
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  0.0             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491            unknown                unknown         unknown
# 20221227106494            unknown                unknown         unknown
# 20221227106497                VMC                unknown         unknown
# 20221227106498            unknown                unknown         unknown
# 20221230106513            unknown                unknown         unknown
#
#                 Publication.Date
# Event.Id
# 20001218X45444           unknown
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494           unknown
# 20221227106497        27-12-2022
# 20221227106498           unknown
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
aviation_data.sample(10)
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001214X39571           Accident      FTW84FA237  1984-05-20
# 20190903X30852           Accident      CEN19LA313  2019-09-03
# 20001214X44470           Accident      CHI83LA414  1983-09-05
# 20110830X20904           Accident      CEN11WA602  2011-07-29
# 20021118X05482           Accident      SEA03LA007  2002-11-05
# 20001214X44652           Accident      MKC83LA221  1983-09-17
# 20001211X14052           Accident      SEA92LA058  1992-01-09
# 20220301104710           Accident      GAA22WA111  2022-02-28
# 20001214X38285           Accident      MIA86LA039  1985-11-30
# 20080908X01404           Accident      DFW08FA212  2008-08-24
#
#                                          Location         Country  \
# Event.Id
# 20001214X39571                          TULSA, OK   United States
# 20190903X30852                           Mack, CO   United States
# 20001214X44470                    WAYNESVILLE, OH   United States
# 20110830X20904              Leeds, United Kingdom  United Kingdom
# 20021118X05482                        Bozeman, MT   United States
# 20001214X44652                    KANSAS CITY, MO   United States
# 20001211X14052                        SEATTLE, WA   United States
# 20220301104710  South Goulburn Island Aerodrome,   American Samoa
# 20001214X38285                      CEDAR KEY, FL   United States
# 20080908X01404                           Yuma, CO   United States
#
#                Airport.Code            Airport.Name Injury.Severity  \
# Event.Id
# 20001214X39571      unknown                 unknown        Fatal(1)
# 20190903X30852         10CO               Mack Mesa       Non-Fatal
# 20001214X44470          401             WAYNESVILLE       Non-Fatal
# 20110830X20904      unknown                 unknown         unknown
# 20021118X05482          BZN          Gallatin Field        Fatal(1)
# 20001214X44652          MKC    KANSAS CITY DOWNTOWN       Non-Fatal
# 20001211X14052      unknown                 unknown       Non-Fatal
# 20220301104710      unknown                 unknown           Fatal
# 20001214X38285          CDK         GEORGE T. LEWIS       Non-Fatal
# 20080908X01404          2V6  Yuma Municipal Airport           Fatal
#
#                Aircraft.damage Registration.Number  ...    Engine.Type  \
# Event.Id                                            ...
# 20001214X39571       Destroyed              N4239D  ...  Reciprocating
# 20190903X30852     Substantial                N2XF  ...  Reciprocating
# 20001214X44470       Destroyed              N2562N  ...  Reciprocating
# 20110830X20904     Substantial              G-CEMS  ...            NaN
# 20021118X05482       Destroyed               N41RJ  ...  Reciprocating
# 20001214X44652     Substantial              N42966  ...  Reciprocating
# 20001211X14052     Substantial              N91056  ...  Reciprocating
# 20220301104710       Destroyed              VH-IDW  ...            NaN
# 20001214X38285     Substantial              N136AV  ...  Reciprocating
# 20080908X01404     Substantial              N5476P  ...  Reciprocating
#
#                Purpose.of.flight Total.Fatal.Injuries  Total.Serious.Injuries  \
# Event.Id
# 20001214X39571          Personal                  1.0                     0.0
# 20190903X30852          Business                  0.0                     0.0
# 20001214X44470          Personal                  0.0                     0.0
# 20110830X20904           unknown                  0.0                     0.0
# 20021118X05482          Personal                  1.0                     0.0
# 20001214X44652          Personal                  0.0                     0.0
# 20001211X14052           Unknown                  0.0                     0.0
# 20220301104710           unknown                  1.0                     0.0
# 20001214X38285          Personal                  0.0                     0.0
# 20080908X01404          Personal                  3.0                     0.0
#
#                Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# Event.Id
# 20001214X39571                  0.0             0.0                VMC
# 20190903X30852                  0.0             1.0                VMC
# 20001214X44470                  0.0             1.0                VMC
# 20110830X20904                  0.0             0.0            unknown
# 20021118X05482                  0.0             0.0                VMC
# 20001214X44652                  0.0             2.0                VMC
# 20001211X14052                  0.0             1.0                VMC
# 20220301104710                  1.0             0.0            unknown
# 20001214X38285                  2.0             2.0                VMC
# 20080908X01404                  0.0             0.0                IMC
#
#                 Broad.phase.of.flight  \
# Event.Id
# 20001214X39571                  Climb
# 20190903X30852                unknown
# 20001214X44470              Go-around
# 20110830X20904                unknown
# 20021118X05482               Approach
# 20001214X44652                   Taxi
# 20001211X14052                Descent
# 20220301104710                unknown
# 20001214X38285                Landing
# 20080908X01404                unknown
#
#                                                     Report.Status  \
# Event.Id
# 20001214X39571                                     Probable Cause
# 20190903X30852  A propeller overspeed due to failure of the el...
# 20001214X44470                                     Probable Cause
# 20110830X20904                                            unknown
# 20021118X05482                                     Probable Cause
# 20001214X44652                                     Probable Cause
# 20001211X14052                                     Probable Cause
# 20220301104710                                            unknown
# 20001214X38285                                     Probable Cause
# 20080908X01404  The pilot's failure to maintain control of the...
#
#                 Publication.Date
# Event.Id
# 20001214X39571           unknown
# 20190903X30852        28-01-2021
# 20001214X44470           unknown
# 20110830X20904        25-09-2020
# 20021118X05482        30-09-2003
# 20001214X44652           unknown
# 20001211X14052        13-08-1993
# 20220301104710        10-03-2022
# 20001214X38285           unknown
# 20080908X01404        25-09-2020
#
# [10 rows x 24 columns]

# %% [markdown]
# ### 4.3 Checking for Duplicates

# %%
duplicates = aviation_data[aviation_data.duplicated()]
print(len(duplicates))
duplicates.head()
# Out:
# 0
# Empty DataFrame
# Columns: [Investigation.Type, Accident.Number, Event.Date, Location, Country, Airport.Code, Airport.Name, Injury.Severity, Aircraft.damage, Registration.Number, Make, Model, Amateur.Built, Number.of.Engines, Engine.Type, Purpose.of.flight, Total.Fatal.Injuries, Total.Serious.Injuries, Total.Minor.Injuries, Total.Uninjured, Weather.Condition, Broad.phase.of.flight, Report.Status, Publication.Date]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### 4.4 Checking for extraneouse values

# %%
for col in aviation_data.columns:
    print(col, '\n', aviation_data[col].value_counts(normalize=True).head(), '\n\n')
# Out:
# Investigation.Type
#  Investigation.Type
# Accident    0.956418
# Incident    0.043582
# Name: proportion, dtype: float64
#
#
# Accident.Number
#  Accident.Number
# CEN22LA149    0.000022
# WPR23LA041    0.000022
# WPR23LA045    0.000022
# DCA22WA214    0.000022
# DCA22WA089    0.000022
# Name: proportion, dtype: float64
#
#
# Event.Date
#  Event.Date
# 1984-06-30    0.000281
# 1982-05-16    0.000281
# 2000-07-08    0.000281
# 1983-08-05    0.000270
# 1984-08-25    0.000270
# Name: proportion, dtype: float64
#
#
# Location
#  Location
# ANCHORAGE, AK      0.004882
# MIAMI, FL          0.002250
# ALBUQUERQUE, NM    0.002205
# HOUSTON, TX        0.002171
# CHICAGO, IL        0.002070
# Name: proportion, dtype: float64
#
#
# Country
#  Country
# United States     0.925289
# Brazil            0.004207
# Canada            0.004039
# Mexico            0.004027
# United Kingdom    0.003870
# Name: proportion, dtype: float64
#
#
# Airport.Code
#  Airport.Code
# unknown    0.436016
# NONE       0.016740
# PVT        0.005456
# APA        0.001800
# ORD        0.001676
# Name: proportion, dtype: float64
#
#
# Airport.Name
#  Airport.Name
# unknown             0.407081
# Private             0.002700
# PRIVATE             0.002520
# Private Airstrip    0.001721
# NONE                0.001642
# Name: proportion, dtype: float64
#
#
# Injury.Severity
#  Injury.Severity
# Non-Fatal    0.757765
# Fatal(1)     0.069379
# Fatal        0.059197
# Fatal(2)     0.041749
# Incident     0.024964
# Name: proportion, dtype: float64
#
#
# Aircraft.damage
#  Aircraft.damage
# Substantial    0.721664
# Destroyed      0.209508
# unknown        0.035932
# Minor          0.031556
# Unknown        0.001339
# Name: proportion, dtype: float64
#
#
# Registration.Number
#  Registration.Number
# unknown    0.015615
# NONE       0.003870
# UNREG      0.001417
# UNK        0.000146
# USAF       0.000101
# Name: proportion, dtype: float64
#
#
# Make
#  Make
# Cessna    0.250053
# Piper     0.135326
# CESSNA    0.055372
# Beech     0.048712
# PIPER     0.031961
# Name: proportion, dtype: float64
#
#
# Model
#  Model
# 152          0.026629
# 172          0.019755
# 172N         0.013095
# PA-28-140    0.010485
# 150          0.009326
# Name: proportion, dtype: float64
#
#
# Amateur.Built
#  Amateur.Built
# No         0.903509
# Yes        0.095344
# unknown    0.001147
# Name: proportion, dtype: float64
#
#
# Number.of.Engines
#  Number.of.Engines
# 1.0    0.782797
# 2.0    0.124639
# 0.0    0.082237
# 3.0    0.005434
# 4.0    0.004849
# Name: proportion, dtype: float64
#
#
# Engine.Type
#  Engine.Type
# Reciprocating    0.850073
# Turbo Shaft      0.044124
# Turbo Prop       0.041458
# Turbo Fan        0.030333
# Unknown          0.025075
# Name: proportion, dtype: float64
#
#
# Purpose.of.flight
#  Purpose.of.flight
# Personal              0.556289
# Instructional         0.119261
# Unknown               0.076522
# unknown               0.069660
# Aerial Application    0.053010
# Name: proportion, dtype: float64
#
#
# Total.Fatal.Injuries
#  Total.Fatal.Injuries
# 0.0    0.799604
# 1.0    0.099934
# 2.0    0.058196
# 3.0    0.017876
# 4.0    0.012409
# Name: proportion, dtype: float64
#
#
# Total.Serious.Injuries
#  Total.Serious.Injuries
# 0.0    0.852738
# 1.0    0.102656
# 2.0    0.031669
# 3.0    0.007076
# 4.0    0.002902
# Name: proportion, dtype: float64
#
#
# Total.Minor.Injuries
#  Total.Minor.Injuries
# 0.0    0.825603
# 1.0    0.116100
# 2.0    0.040230
# 3.0    0.008820
# 4.0    0.004185
# Name: proportion, dtype: float64
#
#
# Total.Uninjured
#  Total.Uninjured
# 0.0    0.402648
# 1.0    0.282386
# 2.0    0.179865
# 3.0    0.048521
# 4.0    0.029947
# Name: proportion, dtype: float64
#
#
# Weather.Condition
#  Weather.Condition
# VMC        0.869658
# IMC        0.067230
# unknown    0.050535
# UNK        0.009630
# Unk        0.002947
# Name: proportion, dtype: float64
#
#
# Broad.phase.of.flight
#  Broad.phase.of.flight
# unknown        0.305606
# Landing        0.173565
# Takeoff        0.140546
# Cruise         0.115526
# Maneuvering    0.091620
# Name: proportion, dtype: float64
#
#
# Report.Status
#  Report.Status
# Probable Cause    0.694732
# unknown           0.071820
# Foreign           0.022489
# <br /><br />      0.001879
# Factual           0.001631
# Name: proportion, dtype: float64
#
#
# Publication.Date
#  Publication.Date
# 25-09-2020    0.191464
# unknown       0.154924
# 26-09-2020    0.019901
# 03-11-2020    0.012994
# 31-03-1993    0.005085
# Name: proportion, dtype: float64

# %%
# confirming if there are still missing values in the data
aviation_data.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Engine.Type               7096
# Investigation.Type           0
# Accident.Number              0
# Report.Status                0
# Broad.phase.of.flight        0
# Weather.Condition            0
# Total.Uninjured              0
# Total.Minor.Injuries         0
# Total.Serious.Injuries       0
# Total.Fatal.Injuries         0
# dtype: int64

# %% [markdown]
# There are 7096 missing values in Engine. Type columns.

# %%
# Handling the remaining missing values in the Engine.Type column

aviation_data['Engine.Type']= aviation_data['Engine.Type'].fillna("Unknown")
aviation_data
# Out:
#                Investigation.Type Accident.Number  Event.Date  \
# Event.Id
# 20001218X45444           Accident      SEA87LA080  1948-10-24
# 20001218X45447           Accident      LAX94LA336  1962-07-19
# 20061025X01555           Accident      NYC07LA005  1974-08-30
# 20001218X45448           Accident      LAX96LA321  1977-06-19
# 20041105X01764           Accident      CHI79FA064  1979-08-02
# ...                           ...             ...         ...
# 20221227106491           Accident      ERA23LA093  2022-12-26
# 20221227106494           Accident      ERA23LA095  2022-12-26
# 20221227106497           Accident      WPR23LA075  2022-12-26
# 20221227106498           Accident      WPR23LA076  2022-12-26
# 20221230106513           Accident      ERA23LA097  2022-12-29
#
#                        Location        Country Airport.Code Airport.Name  \
# Event.Id
# 20001218X45444  MOOSE CREEK, ID  United States      unknown      unknown
# 20001218X45447   BRIDGEPORT, CA  United States      unknown      unknown
# 20061025X01555    Saltville, VA  United States      unknown      unknown
# 20001218X45448       EUREKA, CA  United States      unknown      unknown
# 20041105X01764       Canton, OH  United States      unknown      unknown
# ...                         ...            ...          ...          ...
# 20221227106491    Annapolis, MD  United States      unknown      unknown
# 20221227106494      Hampton, NH  United States      unknown      unknown
# 20221227106497       Payson, AZ  United States          PAN       PAYSON
# 20221227106498       Morgan, UT  United States      unknown      unknown
# 20221230106513       Athens, GA  United States      unknown      unknown
#
#                Injury.Severity Aircraft.damage Registration.Number  ...  \
# Event.Id                                                            ...
# 20001218X45444        Fatal(2)       Destroyed              NC6404  ...
# 20001218X45447        Fatal(4)       Destroyed              N5069P  ...
# 20061025X01555        Fatal(3)       Destroyed              N5142R  ...
# 20001218X45448        Fatal(2)       Destroyed              N1168J  ...
# 20041105X01764        Fatal(1)       Destroyed               N15NY  ...
# ...                        ...             ...                 ...  ...
# 20221227106491           Minor         unknown              N1867H  ...
# 20221227106494         unknown         unknown              N2895Z  ...
# 20221227106497       Non-Fatal     Substantial              N749PJ  ...
# 20221227106498         unknown         unknown              N210CU  ...
# 20221230106513           Minor         unknown              N9026P  ...
#
#                   Engine.Type Purpose.of.flight Total.Fatal.Injuries  \
# Event.Id
# 20001218X45444  Reciprocating          Personal                  2.0
# 20001218X45447  Reciprocating          Personal                  4.0
# 20061025X01555  Reciprocating          Personal                  3.0
# 20001218X45448  Reciprocating          Personal                  2.0
# 20041105X01764        Unknown          Personal                  1.0
# ...                       ...               ...                  ...
# 20221227106491        Unknown          Personal                  0.0
# 20221227106494        Unknown           unknown                  0.0
# 20221227106497        Unknown          Personal                  0.0
# 20221227106498        Unknown          Personal                  0.0
# 20221230106513        Unknown          Personal                  0.0
#
#                 Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# Event.Id
# 20001218X45444                     0.0                  0.0             0.0
# 20001218X45447                     0.0                  0.0             0.0
# 20061025X01555                     0.0                  0.0             0.0
# 20001218X45448                     0.0                  0.0             0.0
# 20041105X01764                     2.0                  0.0             0.0
# ...                                ...                  ...             ...
# 20221227106491                     1.0                  0.0             0.0
# 20221227106494                     0.0                  0.0             0.0
# 20221227106497                     0.0                  0.0             1.0
# 20221227106498                     0.0                  0.0             0.0
# 20221230106513                     1.0                  0.0             1.0
#
#                 Weather.Condition  Broad.phase.of.flight   Report.Status  \
# Event.Id
# 20001218X45444                UNK                 Cruise  Probable Cause
# 20001218X45447                UNK                Unknown  Probable Cause
# 20061025X01555                IMC                 Cruise  Probable Cause
# 20001218X45448                IMC                 Cruise  Probable Cause
# 20041105X01764                VMC               Approach  Probable Cause
# ...                           ...                    ...             ...
# 20221227106491            unknown                unknown         unknown
# 20221227106494            unknown                unknown         unknown
# 20221227106497                VMC                unknown         unknown
# 20221227106498            unknown                unknown         unknown
# 20221230106513            unknown                unknown         unknown
#
#                 Publication.Date
# Event.Id
# 20001218X45444           unknown
# 20001218X45447        19-09-1996
# 20061025X01555        26-02-2007
# 20001218X45448        12-09-2000
# 20041105X01764        16-04-1980
# ...                          ...
# 20221227106491        29-12-2022
# 20221227106494           unknown
# 20221227106497        27-12-2022
# 20221227106498           unknown
# 20221230106513        30-12-2022
#
# [88889 rows x 24 columns]

# %%
aviation_data.isnull().sum().sort_values(ascending=False)
# Out:
# Investigation.Type        0
# Accident.Number           0
# Report.Status             0
# Broad.phase.of.flight     0
# Weather.Condition         0
# Total.Uninjured           0
# Total.Minor.Injuries      0
# Total.Serious.Injuries    0
# Total.Fatal.Injuries      0
# Purpose.of.flight         0
# Engine.Type               0
# Number.of.Engines         0
# Amateur.Built             0
# Model                     0
# Make                      0
# Registration.Number       0
# Aircraft.damage           0
# Injury.Severity           0
# Airport.Name              0
# Airport.Code              0
# Country                   0
# Location                  0
# Event.Date                0
# Publication.Date          0
# dtype: int64

# %%
aviation_data.to_csv("cleaned_data.csv", index=False)

# %% [markdown]
# ## 5. Exploratory Data Analysis

# %% [markdown]
# ## 6. Recommendations
